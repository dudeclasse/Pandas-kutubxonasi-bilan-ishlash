# %% [markdown]
# <a href="https://colab.research.google.com/github/dudeclasse/Pandas-kutubxonasi-bilan-ishlash/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 0, 0, 0, 0, 0.25, 0.5, 0.5, 0.5, 0.5, 0.5])
y = np.array([0, 1, 2, 3, 4, 2, 0, 1, 2, 3, 4])

plt.figure(figsize=(4, 5))
plt.scatter(x, y,)
plt.show()
